# %% [markdown]
# # Exploring and Transforming JSON Schemas

# %% [markdown]
# # Introduction
#
# In this lesson, you'll formalize how to explore a JSON file whose structure and schema is unknown to you. This often happens in practice when you are handed a file or stumble upon one with little documentation.

# %% [markdown]
# ## Objectives
# You will be able to:
# * Use the JSON module to load and parse JSON documents
# * Load and explore unknown JSON schemas
# * Convert JSON to a pandas dataframe

# %% [markdown]
# ## Loading the JSON file
#
# Load the data from the file `disease_data.json`.

# %%
#Your code here 
import json

with open('disease_data.json') as f:
    disease_data = json.load(f)

# %% [markdown]
# ## Explore the first and second levels of the schema hierarchy

# %%
from json_utils import peek_hierarchy

peek_hierarchy(disease_data)
# Out:
# {'keys': ['meta', 'data'], 'types': [dict, list]}

# %%
import pandas as pd
from nested_lookup import nested_lookup

cols = nested_lookup('name', disease_data['meta']['view']['columns'])
cols
# Out:
# ['sid',
#  'id',
#  'position',
#  'created_at',
#  'created_meta',
#  'updated_at',
#  'updated_meta',
#  'meta',
#  'YearStart',
#  'YearEnd',
#  'LocationAbbr',
#  'LocationDesc',
#  'DataSource',
#  'Topic',
#  'Question',
#  'Response',
#  'DataValueUnit',
#  'DataValueType',
#  'DataValue',
#  'DataValueAlt',
#  'DataValueFootnoteSymbol',
#  'DatavalueFootnote',
#  'LowConfidenceLimit',
#  'HighConfidenceLimit',
#  'StratificationCategory1',
#  'Stratification1',
#  'StratificationCategory2',
#  'Stratification2',
#  'StratificationCategory3',
#  'Stratification3',
#  'GeoLocation',
#  'ResponseID',
#  'LocationID',
#  'TopicID',
#  'QuestionID',
#  'DataValueTypeID',
#  'StratificationCategoryID1',
#  'StratificationID1',
#  'StratificationCategoryID2',
#  'StratificationID2',
#  'StratificationCategoryID3',
#  'StratificationID3']

# %% [markdown]
# ## Convert to a DataFrame
#
# Create a DataFrame from the JSON file. Be sure to retrive the column names for the dataframe. (Search within the 'meta' key of the master dictionary.) The DataFrame should include all 42 columns.

# %%
def peek_hierarchy(doc):
    if isinstance(doc, dict):
        return {"keys": list(doc.keys()), "types": list(map(type, doc.values()))}
    elif isinstance(doc, list):
        return list(map(type, doc))

# %%
df = pd.json_normalize(disease_data, record_path='data')
df.columns = cols
df.head()
# Out:
#    sid                                    id  position  created_at  \
# 0    1  FF49C41F-CE8D-46C4-9164-653B1227CF6F         1  1527194521
# 1    2  F4468C3D-340A-4CD2-84A3-DF554DFF065E         2  1527194521
# 2    3  65609156-A343-4869-B03F-2BA62E96AC19         3  1527194521
# 3    4  0DB09B00-EFEB-4AC0-9467-A7CBD2B57BF3         4  1527194521
# 4    5  D98DA5BA-6FD6-40F5-A9B1-ABD45E44967B         5  1527194521
#
#   created_meta  updated_at updated_meta  meta YearStart YearEnd  ...  \
# 0       959778  1527194521       959778  None      2016    2016  ...
# 1       959778  1527194521       959778  None      2016    2016  ...
# 2       959778  1527194521       959778  None      2016    2016  ...
# 3       959778  1527194521       959778  None      2016    2016  ...
# 4       959778  1527194521       959778  None      2016    2016  ...
#
#   LocationID TopicID QuestionID DataValueTypeID StratificationCategoryID1  \
# 0         59     ALC     ALC2_2         CRDPREV                   OVERALL
# 1         01     ALC     ALC2_2         CRDPREV                   OVERALL
# 2         02     ALC     ALC2_2         CRDPREV                   OVERALL
# 3         04     ALC     ALC2_2         CRDPREV                   OVERALL
# 4         05     ALC     ALC2_2         CRDPREV                   OVERALL
#
#   StratificationID1 StratificationCategoryID2 StratificationID2  \
# 0               OVR                      None              None
# 1               OVR                      None              None
# 2               OVR                      None              None
# 3               OVR                      None              None
# 4               OVR                      None              None
#
#   StratificationCategoryID3 StratificationID3
# 0                      None              None
# 1                      None              None
# 2                      None              None
# 3                      None              None
# 4                      None              None
#
# [5 rows x 42 columns]

# %%
import numpy as np 
df.applymap(lambda x: np.nan if x is None else x)
# Out:
#           sid                                    id  position  created_at  \
# 0           1  FF49C41F-CE8D-46C4-9164-653B1227CF6F         1  1527194521
# 1           2  F4468C3D-340A-4CD2-84A3-DF554DFF065E         2  1527194521
# 2           3  65609156-A343-4869-B03F-2BA62E96AC19         3  1527194521
# 3           4  0DB09B00-EFEB-4AC0-9467-A7CBD2B57BF3         4  1527194521
# 4           5  D98DA5BA-6FD6-40F5-A9B1-ABD45E44967B         5  1527194521
# ...       ...                                   ...       ...         ...
# 60261  519150  1B28C1DD-B25F-457E-86E4-7D1463BE82C3    519150  1527194644
# 60262  519704  4FF6ADF8-CC4B-4D94-A5B0-7766346A0D3E    519704  1527194644
# 60263  519705  02896705-4A9F-45A2-A84B-923DEA6DC6A2    519705  1527194644
# 60264  519706  4DF2E74C-5043-474B-9739-98B4D8736BDB    519706  1527194644
# 60265  519707  D742712D-EAFE-401B-83BB-AB93F597E907    519707  1527194644
#
#       created_meta  updated_at updated_meta  meta YearStart YearEnd  ...  \
# 0           959778  1527194521       959778   NaN      2016    2016  ...
# 1           959778  1527194521       959778   NaN      2016    2016  ...
# 2           959778  1527194521       959778   NaN      2016    2016  ...
# 3           959778  1527194521       959778   NaN      2016    2016  ...
# 4           959778  1527194521       959778   NaN      2016    2016  ...
# ...            ...         ...          ...   ...       ...     ...  ...
# 60261       959778  1527194644       959778   NaN      2016    2016  ...
# 60262       959778  1527194644       959778   NaN      2016    2016  ...
# 60263       959778  1527194644       959778   NaN      2016    2016  ...
# 60264       959778  1527194644       959778   NaN      2016    2016  ...
# 60265       959778  1527194644       959778   NaN      2016    2016  ...
#
#       LocationID TopicID QuestionID DataValueTypeID StratificationCategoryID1  \
# 0             59     ALC     ALC2_2         CRDPREV                   OVERALL
# 1             01     ALC     ALC2_2         CRDPREV                   OVERALL
# 2             02     ALC     ALC2_2         CRDPREV                   OVERALL
# 3             04     ALC     ALC2_2         CRDPREV                   OVERALL
# 4             05     ALC     ALC2_2         CRDPREV                   OVERALL
# ...          ...     ...        ...             ...                       ...
# 60261         72     DIS     DIS1_0         CRDPREV                      RACE
# 60262         72     OVC     OVC3_1         CRDPREV                      RACE
# 60263         72     OVC     OVC3_1         CRDPREV                      RACE
# 60264         72     OVC     OVC3_1         CRDPREV                      RACE
# 60265         72     OVC     OVC3_1         CRDPREV                      RACE
#
#        StratificationID1 StratificationCategoryID2 StratificationID2  \
# 0                    OVR                       NaN               NaN
# 1                    OVR                       NaN               NaN
# 2                    OVR                       NaN               NaN
# 3                    OVR                       NaN               NaN
# 4                    OVR                       NaN               NaN
# ...                  ...                       ...               ...
# 60261                ASN                       NaN               NaN
# 60262                BLK                       NaN               NaN
# 60263               AIAN                       NaN               NaN
# 60264                ASN                       NaN               NaN
# 60265                WHT                       NaN               NaN
#
#       StratificationCategoryID3 StratificationID3
# 0                           NaN               NaN
# 1                           NaN               NaN
# 2                           NaN               NaN
# 3                           NaN               NaN
# 4                           NaN               NaN
# ...                         ...               ...
# 60261                       NaN               NaN
# 60262                       NaN               NaN
# 60263                       NaN               NaN
# 60264                       NaN               NaN
# 60265                       NaN               NaN
#
# [60266 rows x 42 columns]

# %% [markdown]
# ## Level-Up
# ## Create a bar graph of states with the highest asthma rates for adults age 18+

# %%
#Your code here
df[df.Topic == 'Asthma'].Question.value_counts()
question = 'Current asthma prevalence among adults aged >= 18 years'
view = df[df.Question == question][['LocationAbbr', 'StratificationCategoryID1']]
view.head()
# Out:
#      LocationAbbr StratificationCategoryID1
# 4725           IL                    GENDER
# 5529           IN                    GENDER
# 5632           IA                    GENDER
# 6777           KS                    GENDER
# 7034           KY                    GENDER

# %% [markdown]
# ## Summary
#
# Well done! In this lab you got some extended practice exploring the structure of JSON files, converting json files to pandas DataFrame, and visualizing data!
